# %%
import os
import zipfile

def files_in_folders(root_folder, extension):
    matching_files_array = []
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            _, file_extension = os.path.splitext(file)
            if str(file_extension.lower()) == str(extension.lower()):
                matching_files_array.append(os.path.join(root))
    return matching_files_array


shapefile_server = 'D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\GroupedFiles'

# %%
# execute once

for file in files_in_folders(shapefile_server, '.shp'):
    zip_file_path = os.path.join(file)
    extract_folder = os.path.splitext(file)[0]
    if not os.path.exists(extract_folder):
        if extract_folder.endswith('.shp'):
            extract_folder = extract_folder[:-3]
        os.makedirs(extract_folder)
    
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[21], line 10
#       8         extract_folder = extract_folder[:-3]
#       9     os.makedirs(extract_folder)
# ---> 10 with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#      11     zip_ref.extractall(extract_folder)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\zipfile.py:1249, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1247 while True:
#    1248     try:
# -> 1249         self.fp = io.open(file, filemode)
#    1250     except OSError:
#    1251         if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'D:\\Data Visualization\\official_maharshtra_india_village_boundary_shapefile-master\\GroupedFiles\\Ahmadnagar'

# %%
# import geopandas as gpd
# from shapely.geometry import Polygon
# import pandas as pd
# complete_shape_file = 'D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\maharashtra.shp'

# empty_gdf = gpd.GeoDataFrame(columns=['id'])
# empty_gdf.loc[0] = [None]

# empty_gdf['geometry'] = None

# empty_gdf.to_file(complete_shape_file)
# complete_shape_fd = gpd.read_file(complete_shape_file)


# for shape_file in files_in_folders(shapefile_server, '.shp'):
#     if len(shape_file.split('.')) != 1:
#         shape_file_fd = gpd.read_file(shape_file)  
#         complete_shape_fd = gpd.GeoDataFrame(pd.concat([complete_shape_fd, shape_file_fd], ignore_index=True), crs=complete_shape_fd.crs)


import geopandas as gpd

complete_shape_file = 'D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\maharashtra.shp'

try:
    # Load the first shapefile as the base GeoDataFrame
    complete_shape_fd = gpd.read_file(complete_shape_file)

    # Iterate through other shapefiles and append their data to the base GeoDataFrame
    for shape_file in files_in_folders(shapefile_server, '.shp'):
        try:
            if len(shape_file.split('.')) != 1:
                shape_file_fd = gpd.read_file(shape_file)  
                complete_shape_fd = gpd.GeoDataFrame(pd.concat([complete_shape_fd, shape_file_fd], ignore_index=True), crs=complete_shape_fd.crs)
        except Exception as e:
            print(f"Error reading file '{shape_file}': {e}")
            # Continue to the next file in case of an error
            continue

    # Save the merged GeoDataFrame as a new shapefile
    complete_shape_fd.to_file('D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\merged_shapefile.shp')

except Exception as e:
    pass
    # print(f"Error reading base shapefile '{complete_shape_file}': {e}")

# %%
gpd.read_file('D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\GroupedFiles\Ahmadnagar\Zip\Ahmadnagar_District_Village_Boundary.shp')

# %%
shape_file_array = files_in_folders(shapefile_server, '.shp')
for  file in shape_file_array:
    if os.path.isdir(file) and file.endswith('shp'):
        os.environ['SHAPE_RESTORE_SHX'] = 'YES'
        os.rename(file, file[:-3])
    # print(file.split('\\')[-1])
    file_shape = gpd.read_file(file+'\\'+file.split('\\')[-1]+'_District_Village_Boundary.shp')
    file_shape.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\GroupedFiles\Akola\Akola\Akola_District_Village_Boundary.shx or D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\GroupedFiles\Akola\Akola\Akola_District_Village_Boundary.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[46], line 6
#       4     os.rename(file, file[:-3])
#       5 # print(file.split('\\')[-1])
# ----> 6 file_shape = gpd.read_file(file+'\\'+file.split('\\')[-1]+'_District_Village_Boundary.shp')
#       7 file_shape.plot()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\io\file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
#     298         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     299     )
#     301 else:
#     302     raise ValueError(f"unknown engine '{engine}'")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\io\file.py:338, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     335     reader = fiona.open
#     337 with fiona_env():
# --> 338     with reader(path_or_bytes, **kwargs) as features:
#     339         crs = features.crs_wkt
#     340         # attempt to get EPSG code
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fiona\__init__.py:305, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     302     path = parse_path(fp)
#     304 if mode in ("a", "r"):
# --> 305     colxn = Collection(
#     306         path,
#     307         mode,
#     308         driver=driver,
#     309         encoding=encoding,
#     310         layer=layer,
#     311         enabled_drivers=enabled_drivers,
#     312         allow_unsupported_drivers=allow_unsupported_drivers,
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
#     316     colxn = Collection(
#     317         path,
#     318         mode,
#    (...)
#     327         **kwargs
#     328     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fiona\collection.py:243, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     241 if self.mode == "r":
#     242     self.session = Session()
# --> 243     self.session.start(self, **kwargs)
#     244 elif self.mode in ("a", "w"):
#     245     self.session = WritingSession()
#
# File fiona\\ogrext.pyx:588, in fiona.ogrext.Session.start()
#
# File fiona\\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: Unable to open D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\GroupedFiles\Akola\Akola\Akola_District_Village_Boundary.shx or D:\Data Visualization\official_maharshtra_india_village_boundary_shapefile-master\GroupedFiles\Akola\Akola\Akola_District_Village_Boundary.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.

# %%
for file in shape_file_array:
    if not file.endswith('.shp'):
        pass
    try:
        file_shape = gpd.read_file(file)
        file_shape.plot()
    except Exception as e:
        pass
